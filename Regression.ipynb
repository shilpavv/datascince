# %% [markdown]
# <a href="https://colab.research.google.com/github/shilpavv/datascince/blob/master/Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris
data=load_iris()
data

# %%
#sort train and test data
x,y=data.data,data.target
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1)

# %%
#using classifier create model
from sklearn.linear_model import LinearRegression
linear=LinearRegression()
linear.fit(x_test,y_test)
# Out:
# LinearRegression()

# %%
#calculate regression code
linear.score(x_test,y_test)
# Out:
# 0.9732185090463504

# %%
#plot
import matplotlib.pyplot as plt
plt.plot(x_test,y_test)
